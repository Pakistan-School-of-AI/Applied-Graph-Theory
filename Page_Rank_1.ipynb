# %% [markdown]
# <a href="https://colab.research.google.com/github/Pakistan-School-of-AI/Applied-Graph-Theory/blob/master/Page_Rank_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# %%
G = nx.barbell_graph(4,2)
nx.draw(G)

# %%
G = nx.barbell_graph(4,3)
nx.draw(G)

# %%
G = nx.barbell_graph(5,3)
nx.draw(G)

# %%
G = nx.complete_graph(4)
nx.draw(G)

# %%
G = nx.cycle_graph(5)
nx.draw(G)

# %%
G = nx.ladder_graph(5)
nx.draw(G)

# %%
G = nx.path_graph(6)
nx.draw(G)

# %%
G = nx.star_graph(5)
nx.draw(G)

# %%
G = nx.star_graph(4)
nx.draw(G)

# %%
G = nx.wheel_graph(4)
nx.draw(G)

# %%
G = nx.wheel_graph(5)
nx.draw(G)

# %%
G = nx.wheel_graph(6)
nx.draw(G)

# %%
G = nx.gnp_random_graph(5, 0.5)
nx.draw(G)

# %%
G = nx.gnp_random_graph(5, 0.5)
nx.draw(G)
